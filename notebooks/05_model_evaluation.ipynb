# %% [markdown]
# # Phase 7 & 8: Model Evaluation and Explainability
# Comparing models and explaining the best one.

# %%
import pandas as pd
import joblib
import shap
import matplotlib.pyplot as plt

model = joblib.load("../ml/models/best_model.pkl")
print(model)
